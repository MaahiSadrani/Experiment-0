# %% [markdown]
# Experiment 0: Introduction to Python

# %%
# Maahi Sadrani
print("Maahi Sadrani")
# Out:
# Maahi Sadrani

# %%
print(2)
# Out:
# 2

# %%
print([1,2,5])
# Out:
# [1, 2, 5]

# %%
print(2)
print([1, 2, 5, 6])
print("Maahi")
# Out:
# 2
# [1, 2, 5, 6]
# Maahi

# %%
a= (2)
b =( [1,2,3])
c = ("Maahi")
print (a,b,c,sep ="\n")
# Out:
# 2
# [1, 2, 3]
# Maahi
